# %% [markdown]
# # Métodos Específicos de Lista em Python

# %% [markdown]
# ## `list.append(valor)`
# Adiciona um valor ao final de uma lista

# %%
# Uso:
vendas = [150, 320]
vendas.append(110)

#Resultado:
print(vendas)
# Out:
# [150, 320, 110]

# %% [markdown]
# ## `list.extend(lista2)`
# Adiciona todos os valores da lista2 na lista original

# %%
# Uso:
vendas = [150, 320, 110, 450, 390, 370]
vendas_2semestre = [440, 470, 900, 1000, 1100, 1050]
vendas.extend(vendas_2semestre)

# Resultado:
print(vendas)
# Out:
# [150, 320, 110, 450, 390, 370, 440, 470, 900, 1000, 1100, 1050]

# %% [markdown]
# ## `list.insert(posicao, valor)`
# Adiciona um valor em uma posição específica em uma lista. Não é recomendado usar a não ser que seja realmente necessário inserir em uma posição específica, porque o método append é mais eficiente.

# %%
# Uso:
frutas = ['uva', 'banana']
frutas.insert(0, 'maçã')

# Resultado:
print(frutas)
# Out:
# ['maçã', 'uva', 'banana']

# %% [markdown]
# ## `list.remove(valor)`
# Remove o valor da lista (apenas a 1ª ocorrência, então caso haja 2 vezes o valor na lista, apenas a 1ª será removida). Além disso, dá um erro caso valor não exista dentro da lista.

# %%
# Uso:
alunos = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus']
alunos.remove('Paulo')

# Resultado:
print(alunos)

# %% [markdown]
# ## `list.pop(posicao)`
# Remove o item que está na posicao (índice) passado. Além disso, esse item é dado como resultado do pop, portanto pode ser armazenado em uma variável ou usado para outra coisa na mesma linha de código.

# %%
# Uso:
funcionarios = ['João', 'Julia', 'Maria', 'Janaína', 'Paulo', 'Lucas']
demitido = funcionarios.pop(1)

# Resultado:
print(demitido)
print(funcionarios)
# Out:
# Julia
# ['João', 'Maria', 'Janaína', 'Paulo', 'Lucas']

# %% [markdown]
# ## `list.clear()`
# Remove todos os itens de uma lista

# %%
# Uso:
jogadores = ['João', 'Everton', 'Fernando', 'Lucas', 'Gustavo', 'Fred']
jogadores.clear()

# Resultado:
print(jogadores)
# Out:
# []

# %% [markdown]
# ## `list.index(valor)`
# Retorna a posição do valor dentro da lista (em qual índice está o valor). Dá erro caso não haja o valor dentro da lista.

# %%
# Uso:
candidatos = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus']
posicao_ana = candidatos.index('Ana')

# Resultado:
print(posicao_ana)
# Out:
# 3

# %% [markdown]
# ## `list.count(valor)`
# Retorna a quantidade de vezes que o valor aparece na lista

# %%
# Uso:
nomes = ['João', 'Ana', 'Maria', 'Ana', 'Pedro', 'Matheus', 'Ana']
qtde_ana = nomes.count('Ana')

# Resultado:
print(qtde_ana)
# Out:
# 3

# %% [markdown]
# ## `list.sort(reverse=False)`
# Ordena os valores da lista em ordem crescente, ou alfabética, (reverse=False) ou decrescente (reverse=True).

# %%
# Uso:
valores = [355, 605, 75, 250]
valores.sort(reverse=True)

# Resultado:
print(valores)
# Out:
# [605, 355, 250, 75]

# %% [markdown]
# ## `list.reverse()`
# Inverte a ordem dos elementos de uma lista.

# %%
# Uso:
nums = [150, 300, 190, 480, 263, 124, 542]
nums.reverse()

# Resultado:
print(nums)
# Out:
# [542, 124, 263, 480, 190, 300, 150]

# %% [markdown]
# ## `list.copy()`
# Cria uma cópia da lista original. Outra opção é fazer lista2 = lista1[:]

# %%
# Uso
vendas = [150, 300, 190, 480]
vendas2 = vendas.copy()

# Resultado
print(vendas2)
# Out:
# [150, 300, 190, 480]
